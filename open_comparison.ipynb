# %%
import uproot
import awkward as ak

f1 = uproot.open("jets_RDF.root")
f2 = uproot.open("jets_coffea.root")

#File type
print("RDataFrame: ", f1["Events"].classname)
print("Coffea: ", f2["Events"].classname)

#Branches
#print(f1["Events"].keys())
#print(f2["Events"].keys())
print("Same keys:", set(f1["Events"].keys()) == set(f2["Events"].keys()))
print("Same number", (f1["Events"].num_entries)==(f2["Events"].num_entries))

#Compare data
for branch in f1["Events"].keys():
    same = ak.almost_equal(
        f1["Events"][branch].array(),
        f2["Events"][branch].array()
    ) #Cheks if two awkward arrays are the same
    print(branch, same)
# Out:
# RDataFrame:  TTree
# Coffea:  ROOT::RNTuple
# Same keys: True
# Same number True
# nJet False
# Jet_area True
# Jet_bRegCorr True
# Jet_bRegRes True
# Jet_btagCMVA True
# Jet_btagCSVV2 True
# Jet_btagDeepB True
# Jet_btagDeepC True
# Jet_btagDeepFlavB True
# Jet_btagDeepFlavC True
# Jet_chEmEF True
# Jet_chHEF True
# Jet_cleanmask True
# Jet_electronIdx1 True
# Jet_electronIdx2 True
# Jet_eta True
# Jet_genJetIdx True
# Jet_hadronFlavour True
# Jet_jercCHF True
# Jet_jercCHPUF True
# Jet_jetId True
# Jet_mass True
# Jet_muEF True
# Jet_muonIdx1 True
# Jet_muonIdx2 True
# Jet_muonSubtrFactor True
# Jet_nConstituents True
# Jet_nElectrons True
# Jet_nMuons True
# Jet_neEmEF True
# Jet_neHEF True
# Jet_partonFlavour True
# Jet_phi True
# Jet_pt True
# Jet_puId True
# Jet_qgl True
# Jet_rawFactor True
